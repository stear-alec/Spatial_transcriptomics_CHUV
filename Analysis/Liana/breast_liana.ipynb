# %%
# import liana
import liana as li
# needed for visualization and toy data
import scanpy as sc
import pandas as pd
import numpy as np
import os

# %%
path = "/work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium/xenium_objs/anndata/breast_B1_1.h5ad"
chuvio_B1_1 = sc.read_h5ad(path)

# %%
chuvio_B1_1
# Out:
# AnnData object with n_obs × n_vars = 123565 × 270
#     obs: 'orig.ident', 'nCount_originalexp', 'nFeature_originalexp', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'sample_id', 'sum', 'detected', 'subsets_Mito_sum', 'subsets_Mito_detected', 'subsets_Mito_percent', 'total', 'libsize_drop', 'sizeFactor', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'rctd_first_type', 'rctd_spot_class', 'rctd_ref_lungbreast_first_type', 'rctd_ref_lungbreast_spot_class', 'ident'
#     uns: 'X_name'
#     obsm: 'PCA', 'UMAP'
#     layers: 'logcounts'

# %%
chuvio_B1_1.obs
# Out:
#                 orig.ident  nCount_originalexp  nFeature_originalexp  \
# B1_1_aaaachep-1         B1               176.0                    80
# B1_1_aaaadpbi-1         B1               241.0                    66
# B1_1_aaaaepld-1         B1               125.0                    53
# B1_1_aaabbgmk-1         B1               102.0                    35
# B1_1_aaabpgij-1         B1               110.0                    55
# ...                    ...                 ...                   ...
# B1_1_oiijncjg-1         B1               182.0                    53
# B1_1_oiikcmdg-1         B1               144.0                    56
# B1_1_oiikehml-1         B1                46.0                    26
# B1_1_oiikpjgm-1         B1                22.0                    17
# B1_1_oiilhjip-1         B1                59.0                    29
#
#                          cell_id   x_centroid   y_centroid  transcript_counts  \
# B1_1_aaaachep-1  B1_1_aaaachep-1  1671.557617  2203.856201                176
# B1_1_aaaadpbi-1  B1_1_aaaadpbi-1  1653.334229  2207.638916                241
# B1_1_aaaaepld-1  B1_1_aaaaepld-1  1663.231079  2214.756104                125
# B1_1_aaabbgmk-1  B1_1_aaabbgmk-1  1645.274536  2217.458984                102
# B1_1_aaabpgij-1  B1_1_aaabpgij-1  1649.982544  2227.356445                110
# ...                          ...          ...          ...                ...
# B1_1_oiijncjg-1  B1_1_oiijncjg-1  5991.727051  1417.232788                182
# B1_1_oiikcmdg-1  B1_1_oiikcmdg-1  6009.589355  1417.129761                145
# B1_1_oiikehml-1  B1_1_oiikehml-1  6042.314941  1416.647461                 46
# B1_1_oiikpjgm-1  B1_1_oiikpjgm-1  5984.858398  1380.782715                 22
# B1_1_oiilhjip-1  B1_1_oiilhjip-1  6022.083984  1422.252563                 59
#
#                  control_probe_counts  control_codeword_counts  \
# B1_1_aaaachep-1                     0                        0
# B1_1_aaaadpbi-1                     0                        0
# B1_1_aaaaepld-1                     0                        0
# B1_1_aaabbgmk-1                     0                        0
# B1_1_aaabpgij-1                     0                        0
# ...                               ...                      ...
# B1_1_oiijncjg-1                     0                        0
# B1_1_oiikcmdg-1                     0                        0
# B1_1_oiikehml-1                     0                        0
# B1_1_oiikpjgm-1                     0                        0
# B1_1_oiilhjip-1                     0                        0
#
#                  unassigned_codeword_counts  ...  subsets_Mito_detected  \
# B1_1_aaaachep-1                           0  ...                      0
# B1_1_aaaadpbi-1                           0  ...                      0
# B1_1_aaaaepld-1                           0  ...                      0
# B1_1_aaabbgmk-1                           0  ...                      0
# B1_1_aaabpgij-1                           0  ...                      0
# ...                                     ...  ...                    ...
# B1_1_oiijncjg-1                           0  ...                      0
# B1_1_oiikcmdg-1                           0  ...                      0
# B1_1_oiikehml-1                           0  ...                      0
# B1_1_oiikpjgm-1                           0  ...                      0
# B1_1_oiilhjip-1                           0  ...                      0
#
#                  subsets_Mito_percent  total  libsize_drop sizeFactor  \
# B1_1_aaaachep-1                   0.0  176.0         False   1.117938
# B1_1_aaaadpbi-1                   0.0  241.0         False   1.530812
# B1_1_aaaaepld-1                   0.0  125.0         False   0.793990
# B1_1_aaabbgmk-1                   0.0  102.0         False   0.647896
# B1_1_aaabpgij-1                   0.0  110.0         False   0.698711
# ...                               ...    ...           ...        ...
# B1_1_oiijncjg-1                   0.0  182.0         False   1.156049
# B1_1_oiikcmdg-1                   0.0  145.0         False   0.914676
# B1_1_oiikehml-1                   0.0   46.0         False   0.292188
# B1_1_oiikpjgm-1                   0.0   22.0         False   0.139742
# B1_1_oiilhjip-1                   0.0   59.0         False   0.374763
#
#                  nCount_SCT  nFeature_SCT  SCT_snn_res.0.8  seurat_clusters  \
# B1_1_aaaachep-1       149.0            80                0                0
# B1_1_aaaadpbi-1       151.0            62                3                3
# B1_1_aaaaepld-1       128.0            53                3                3
# B1_1_aaabbgmk-1       126.0            35                3                3
# B1_1_aaabpgij-1       119.0            55               10               10
# ...                     ...           ...              ...              ...
# B1_1_oiijncjg-1       149.0            53                3                3
# B1_1_oiikcmdg-1       142.0            56                3                3
# B1_1_oiikehml-1       102.0            31               15               15
# B1_1_oiikpjgm-1        87.0            23                5                5
# B1_1_oiilhjip-1       114.0            29                5                5
#
#                  ident
# B1_1_aaaachep-1      0
# B1_1_aaaadpbi-1      3
# B1_1_aaaaepld-1      3
# B1_1_aaabbgmk-1      3
# B1_1_aaabpgij-1     10
# ...                ...
# B1_1_oiijncjg-1      3
# B1_1_oiikcmdg-1      3
# B1_1_oiikehml-1     15
# B1_1_oiikpjgm-1      5
# B1_1_oiilhjip-1      5
#
# [123565 rows x 28 columns]

# %%
li.method.rank_aggregate(chuvio_B1_1,
                           groupby='seurat_clusters',
                           resource_name = 'cellchatdb',
                           expr_prop=0.1, # must be expressed in expr_prop fraction of cells
                           min_cells = 5,
                           n_perms = 1000,
                           use_raw = False, # run on log- and library-normalized counts
                           verbose = True,
                           inplace = True
                          )
# Out:
# Using `.X`!
# Converting to sparse csr matrix!
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/astear/pkgs/miniforge3/envs/CellPhoneDB/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# Make sure that normalized counts are passed!
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/astear/pkgs/miniforge3/envs/CellPhoneDB/lib/python3.11/site-packages/liana/method/_pipe_utils/_pre.py:151: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Using resource `cellchatdb`.
# 0.94 of entities in the resource are missing from the data.
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/astear/pkgs/miniforge3/envs/CellPhoneDB/lib/python3.11/site-packages/liana/method/sc/_liana_pipe.py:251: ImplicitModificationWarning: Setting element `.layers['scaled']` of view, initializing view as actual.
# Generating ligand-receptor stats for 123565 samples and 270 features
# Assuming that counts were `natural` log-normalized!
# Running CellPhoneDB
# 100%|██████████| 1000/1000 [00:13<00:00, 74.09it/s]
# Running Connectome
# Running log2FC
# Running NATMI
# Running SingleCellSignalR
# Running CellChat
# 100%|██████████| 1000/1000 [00:26<00:00, 37.31it/s]
