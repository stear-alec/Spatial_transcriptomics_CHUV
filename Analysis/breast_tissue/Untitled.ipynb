# %%
pip install tables
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 37.8 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 91.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.3/378.3 kB 955.0 kB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 2.0 MB/s eta 0:00:00:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Try importing different types of breast tissue datasets ?
# Go to

# %%
# What type of data type do I want ? 
# import transcript , cell_feature_matrix.h5, transcripts.csv.gz
path = '/work/PRTNR/CHUV/DIR/rgottar1/spatial/Xenium/breast/breast_owkin/B1_1/'

# %%
import pandas as pd
import tables

# Assuming 'cell_feature_matrix.h5' contains a dataset named 'data'
data = pd.read_hdf('/work/PRTNR/CHUV/DIR/rgottar1/spatial/Xenium/breast/breast_owkin/B1_1/cell_feature_matrix.h5')

# Now 'data' is a DataFrame containing the contents of the HDF5 file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 import tables
#       4 # Assuming 'cell_feature_matrix.h5' contains a dataset named 'data'
# ----> 5 data = pd.read_hdf('/work/PRTNR/CHUV/DIR/rgottar1/spatial/Xenium/breast/breast_owkin/B1_1/cell_feature_matrix.h5')
#       7 # Now 'data' is a DataFrame containing the contents of the HDF5 file
#
# File /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/astear/pkgs/miniforge3/envs/commot2/lib/python3.11/site-packages/pandas/io/pytables.py:435, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     433 groups = store.groups()
#     434 if len(groups) == 0:
# --> 435     raise ValueError(
#     436         "Dataset(s) incompatible with Pandas data types, "
#     437         "not table, or no datasets found in HDF5 file."
#     438     )
# ...

# %%
import pandas as pd

# Read the compressed CSV file into a DataFrame
df = pd.read_csv(f'{path}transcripts.csv.gz', compression='gzip')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#      transcript_id     cell_id  overlaps_nucleus           feature_name  \
# 0  281612415664156  UNASSIGNED                 0  NegControlProbe_00012
# 1  281612415664157  UNASSIGNED                 0  NegControlProbe_00012
# 2  281612415664170  UNASSIGNED                 0                   LARS
# 3  281612415664184  UNASSIGNED                 0                   MZB1
# 4  281612415664208  UNASSIGNED                 0  NegControlProbe_00014
#
#    x_location  y_location  z_location         qv fov_name  nucleus_distance
# 0   98.604050   2193.5880   12.270564  40.000000      AE3         51.330850
# 1  138.075700   2207.7214   12.313629  40.000000      AE3         34.818497
# 2  147.392880   2238.4624   12.448782  32.020416      AE3         21.303888
# 3   16.124146   2209.7942   12.337914  40.000000      AE3        106.123040
# 4   60.139004   2242.5999   12.573466   9.259405      AE3         55.616993

# %%
len(df
# Out:
#             transcript_id     cell_id  overlaps_nucleus  \
# 0         281612415664156  UNASSIGNED                 0
# 1         281612415664157  UNASSIGNED                 0
# 2         281612415664170  UNASSIGNED                 0
# 3         281612415664184  UNASSIGNED                 0
# 4         281612415664208  UNASSIGNED                 0
# ...                   ...         ...               ...
# 24893773  281668250260533  UNASSIGNED                 0
# 24893774  281668250260534  UNASSIGNED                 0
# 24893775  281668250260536  UNASSIGNED                 0
# 24893776  281668250260537  UNASSIGNED                 0
# 24893777  281668250260539  UNASSIGNED                 0
#
#                    feature_name   x_location  y_location  z_location  \
# 0         NegControlProbe_00012    98.604050   2193.5880   12.270564
# 1         NegControlProbe_00012   138.075700   2207.7214   12.313629
# 2                          LARS   147.392880   2238.4624   12.448782
# ...
