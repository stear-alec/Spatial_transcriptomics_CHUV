# %%
pip install nichecompass
# Out:
# ...
#   Using cached nichecompass-0.1.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached scglue-0.3.2-py3-none-any.whl.metadata (6.0 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# ...
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# ...
#   Using cached gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached pynvml-11.5.0-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
